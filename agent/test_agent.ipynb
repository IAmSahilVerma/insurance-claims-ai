# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from ml.predict import predict_claim
from fraud_agent import investigate_claim
import pandas as pd

# %%
high_risk_claim = {
    "Month": "Dec",
    "WeekOfMonth": "5",
    "DayOfWeek": "Friday",
    "Make": "BMW",
    "AccidentArea": "Urban",
    "DayOfWeekClaimed": "Monday",
    "MonthClaimed": "Jan",
    "WeekOfMonthClaimed": "1",
    "Sex": "Male",
    "MaritalStatus": "Single",
    "Age": 23,
    "Fault": "Policy Holder",
    "PolicyType": "Sport - Collision",
    "VehicleCategory": "Sport",
    "VehiclePrice": "more than 69000",
    "Deductible": 300,
    "DriverRating": 1,
    "Days_Policy_Accident": "more than 30",
    "Days_Policy_Claim": "more than 30",
    "PastNumberOfClaims": "4 to 8",
    "AgeOfVehicle": "7 years",
    "AgeOfPolicyHolder": "18 to 20",
    "PoliceReportFiled": "No",
    "WitnessPresent": "No",
    "AgentType": "External",
    "NumberOfSuppliments": "more than 5",
    "NumberOfCars": "3 to 4",
    "BasePolicy": "Collision"
}

# %%
from rag.retriever import retrieve_rules
retrieve_rules()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from rag.retriever import retrieve_rules
# ----> 2 retrieve_rules()
#
# File d:\Github\insurance-claims-ai\rag\retriever.py:2, in retrieve_rules()
#       1 def retrieve_rules():
# ----> 2     with open("fraud_rules.txt", "r") as f:
#       3         rules = f.read()
#       4     return rules
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fraud_rules.txt'

# %%
response = investigate_claim(high_risk_claim)
print(response)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = investigate_claim(high_risk_claim)
#       2 print(response)
#
# File d:\Github\insurance-claims-ai\agent\fraud_agent.py:14, in investigate_claim(data)
#      12 def investigate_claim(data: dict):
#      13     prediction = predict_claim(data)
# ---> 14     rules = retrieve_rules()
#      16     prompt = f"""
#      17     You are an insurance fraud investigator.
#      18
#    (...)
#      31     3. Recommended Action
#      32     """
#      34     response = client.chat.completions.create(
#      35         model="gpt-40-mini",
#      36         messages=[{"role": "user", "content": prompt}]
#      37     )
#
# File d:\Github\insurance-claims-ai\rag\retriever.py:2, in retrieve_rules()
#       1 def retrieve_rules():
# ----> 2     with open("fraud_rules.txt", "r") as f:
#       3         rules = f.read()
#       4     return rules
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fraud_rules.txt'
